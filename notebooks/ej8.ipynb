# %%
import sys
sys.path.append('../src')

# %%
import ej8_cifrado
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import ej8_cifrado
#
# ModuleNotFoundError: No module named 'ej8_cifrado'

# %%
ej8_cifrado.cifrado_cesar("hola",3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ej8_cifrado.cifrado_cesar("hola",3)
#
# NameError: name 'ej8_cifrado' is not defined
