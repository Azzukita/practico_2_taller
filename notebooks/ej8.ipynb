# %%
import sys
sys.path.append('../src')

# %%
import cifrado
# Out:
# Ingrese un mensaje:  hola
# Ingrese el desplazamiento:  3
# Mensaje cifrado:    krod
# Mensaje descifrado: hola

# %%
cifrado.cifrado_cesar("hola",3)
# Out:
# 'krod'

# %%
descifrado.cifrado_cesar("krod",3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 descifrado.cifrado_cesar("krod",3)
#
# NameError: name 'descifrado' is not defined

# %%
cifrado.descifrado_cesar(krod,3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 cifrado.descifrado_cesar(krod,3)
#
# AttributeError: module 'cifrado' has no attribute 'descifrado_cesar'

# %%
cifrado.descifrar_cesar("krod", 3)
# Out:
# 'hola'

# %%
cifrado.cifrado("Lara",3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cifrado.cifrado("Lara",3)
#
# TypeError: 'str' object is not callable

# %%
cifrado.cifrado_cesar("lara",3)
# Out:
# 'odud'

# %%
cifrado.descifrar_cesar("odud", 3)
# Out:
# 'lara'
