# %%
import sys
sys.path.append('../src')

# %%
import ej10
# Out:
# ...
#   RONDA: Entrada
#   Ganador de la ronda: Camila (26 pts)
# ...
# Pos   Participante     Ronda  Acumulado
# -------------------------------------------------------
# 1     Camila              26         26
# 2     Valentina           24         24
# 3     Lucia               24         24
# 4     Mateo               22         22
# 5     Santiago            19         19
#
# ...
#   RONDA: Plato principal
#   Ganador de la ronda: Valentina (26 pts)
# ...
# Pos   Participante     Ronda  Acumulado
# -------------------------------------------------------
# 1     Valentina           26         50
# 2     Mateo               24         46
# 3     Camila              20         46
# 4     Lucia               22         46
# 5     Santiago            25         44
#
# ...
#   RONDA: Postre
#   Ganador de la ronda: Lucia (27 pts)
# ...
# Pos   Participante     Ronda  Acumulado
# -------------------------------------------------------
# 1     Lucia               27         73
# 2     Valentina           22         72
# ...

# %%
ej10.simularcompetencia(rounds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ej10.simularcompetencia(rounds)
#
# AttributeError: module 'ej10' has no attribute 'simularcompetencia'

# %%
ej10.simular_competencia(ej10.rounds)
# Out:
# ...
#   RONDA: Entrada
#   Ganador de la ronda: Camila (26 pts)
# ...
# Pos   Participante     Ronda  Acumulado
# -------------------------------------------------------
# 1     Camila              26         26
# 2     Valentina           24         24
# 3     Lucia               24         24
# 4     Mateo               22         22
# 5     Santiago            19         19
#
# ...
#   RONDA: Plato principal
#   Ganador de la ronda: Valentina (26 pts)
# ...
# Pos   Participante     Ronda  Acumulado
# -------------------------------------------------------
# 1     Valentina           26         50
# 2     Mateo               24         46
# 3     Camila              20         46
# 4     Lucia               22         46
# 5     Santiago            25         44
#
# ...
#   RONDA: Postre
#   Ganador de la ronda: Lucia (27 pts)
# ...
# Pos   Participante     Ronda  Acumulado
# -------------------------------------------------------
# 1     Lucia               27         73
# 2     Valentina           22         72
# ...
